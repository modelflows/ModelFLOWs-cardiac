# %% [markdown]
# ### VISUALIZAR IMAGENES EN FORMATO NUMPY .npy

# %%
import numpy as np
import matplotlib.pyplot as plt

# Humanos
arr = np.load("/home/ander/Escritorio/Workshop2025-2026/Databases/Human_ecos/Ecos_tutorials_AI/ecos_orig/ecos_orig_Training/NORM/CTSCXUBO--original--data/CTSCXUBO--original--NORM_000.npy")
# Ratones
#arr = np.load("/home/ander/Escritorio/Workshop2025-2026/Databases/Mice_ecos/Ecos_tutorials_AI/ecos_orig/ecos_orig_Training/CTL/40W_88_LA--original--data/40W_88_LA--original--CTL_0003.npy")
print("Shape:", arr.shape)

# Si es imagen 2D
if len(arr.shape) == 2:
    plt.imshow(arr, cmap="gray")
    plt.colorbar()
    plt.show()

# Si es volumen 3D (por ejemplo DICOM convertido)
elif len(arr.shape) == 3:
    slice_index = arr.shape[0] // 2
    plt.imshow(arr[slice_index], cmap="gray")
    plt.title(f"Slice {slice_index}")
    plt.show()
# Out:
# Shape: (800, 800)
